# %%
import pandas as pd

# %%
df1= pd.read_csv('/content/GoMcUtil.csv')
df2= pd.read_csv('/content/PayMcUtil.csv')

# %%
df1.describe()
# Out:
#        DaysSinceFirstTxn      DaysWTxn
# count       42567.000000  42567.000000
# mean           70.691428     32.060822
# std            52.585447     32.942788
# min             0.000000      1.000000
# 25%            30.000000      6.000000
# 50%            58.000000     21.000000
# 75%           100.000000     48.000000
# max           323.000000    312.000000

# %%
def proc_df(df):
  df=df.loc[df['DaysSinceFirstTxn']> 0]
  df['DaysSinceFirstTxn']= df['DaysSinceFirstTxn']+1
  df['DaysWTxn%']= df['DaysWTxn']/ df['DaysSinceFirstTxn']
  return(df)

# %%
for df in dfs:
  df=df.loc[df['DaysSinceFirstTxn']> 0]
  df['DaysSinceFirstTxn']= df['DaysSinceFirstTxn']+1
  df['DaysWTxn%']= df['DaysWTxn']/ df['DaysSinceFirstTxn']

# %%
df.describe()
# Out:
#        DaysSinceFirstTxn       DaysWTxn      DaysWTxn%
# count      175303.000000  175303.000000  175303.000000
# mean          300.226146     185.793187       0.614790
# std           105.535451      95.347378       0.239461
# min        -17632.000000       1.000000      -0.000057
# 25%           286.000000     111.000000       0.456338
# 50%           355.000000     193.000000       0.649860
# 75%           357.000000     265.000000       0.809524
# max           357.000000     357.000000       1.000000
