# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

worksheet = gc.open('https://docs.google.com/spreadsheets/d/16aRWZBFH6POujlvdlya5IkU0pKLaVewT/edit#gid=1853214482').sheet1

# get_all_values gives a list of rows.
rows = worksheet.get_all_values()
print(rows)

# Convert to a DataFrame and render.
import pandas as pd
pd.DataFrame.from_records(rows)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/gspread/client.py in open(self, title)
#     121                 lambda x: x['name'] == title,
# --> 122                 self.list_spreadsheet_files()
#     123             )
#
# /usr/local/lib/python3.7/dist-packages/gspread/utils.py in finditem(func, seq)
#      28     """
# ---> 29     return next((item for item in seq if func(item)))
#      30
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# SpreadsheetNotFound                       Traceback (most recent call last)
# <ipython-input-4-610cf38ccb98> in <module>()
#       7 gc = gspread.authorize(GoogleCredentials.get_application_default())
#       8
# ----> 9 worksheet = gc.open('https://docs.google.com/spreadsheets/d/16aRWZBFH6POujlvdlya5IkU0pKLaVewT/edit#gid=1853214482').sheet1
#      10
#      11 # get_all_values gives a list of rows.
#
# /usr/local/lib/python3.7/dist-packages/gspread/client.py in open(self, title)
#     128             return Spreadsheet(self, properties)
#     129         except StopIteration:
# --> 130             raise SpreadsheetNotFound
#     131
#     132     def open_by_key(self, key):
#
# SpreadsheetNotFound:
