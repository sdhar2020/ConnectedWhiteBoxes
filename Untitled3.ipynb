# %%
import pandas as pd
df = pd.DataFrame(
    data={"animal_1": ["elk", "pig"], "animal_2": ["dog", "quetzal"]}
)
df.to_markdown()
# Out:
# '|    | animal_1   | animal_2   |\n|---:|:-----------|:-----------|\n|  0 | elk        | dog        |\n|  1 | pig        | quetzal    |'

# %% [markdown]
# |    | animal_1   | animal_2   |
# |---:|:-----------|:-----------|
# |  0 | elk        | dog        |
# |  1 | pig        | quetzal    |
