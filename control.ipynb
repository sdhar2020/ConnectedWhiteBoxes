# %%
import pandas as pd

# %%
cntrl= pd.read_csv('cntrl.csv')

# %%
print(cntrl.as400id.astype('str').tolist())
# Out:
# ['400176', '420292', '402603', '402606', '43102', '402601', '41497', '401132', '402602', '43099', '40302', '402616', '420132', '401883', '42347', '42014', '400214', '400510', '40179', '40106', '402013', '42822', '400809', '40299', '401112', '402633', '402636', '400773', '402631', '400162', '42247', '420361', '43446', '42436', '40005', '43368', '400425', '42346', '420668', '402640', '402029', '402622', '42438', '40936', '43135', '41543', '41460', '420495', '420827', '41469', '40419', '400611', '420459', '40070', '420579', '420559', '401410', '401406', '41498', '420658', '420168', '420492', '401485', '402271', '420040', '41580', '402209', '402692', '400870', '402680', '41462', '42455', '40935', '40737', '401084', '42507', '42512', '400825', '420025', '401015', '42445', '413905', '42195', '420119', '400150', '400477', '413899', '402661', '40832', '420029', '400855', '40732', '42411', '42340', '402711', '402682', '401054', '40835', '40831', '420146', '400743', '402659', '400228', '41513'
# ...

# %%
camp= pd.read_csv('indy_mailer2020.csv')

# %%
cntl= set(cntrl.as400id.astype(str).unique())

# %%
cpgn= set(camp.AS400.astype(str).unique())

# %%
len(cpgn)
# Out:
# 566

# %%
len(cntl)
# Out:
# 578

# %%
len(cpgn.union(cntl))
# Out:
# 1144

# %%
len(cpgn.intersection(cntl))
# Out:
# 0

# %%
len(cntl.intersection(cpgn))
# Out:
# 0
