# %%
import pandas as pd

# %%
df = pd.read_csv('/content/DFORE347.csv')

# %%
df1=df.loc[(df.installcap_44== df.installcap_42) & (df.installcap_40== df.installcap_42) & (df.installcap_42== df.installcap_44)]

# %%
df2= df1.groupby('cohort_flag')['installcap_40','installcap_42','installcap_44', 'total_vend_amnt_40', 'total_vend_amnt_42', 'total_vend_amnt_44'].sum()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
df2
# Out:
#              installcap_40  ...  total_vend_amnt_44
# cohort_flag                 ...
# control              28459  ...           496730.07
# test                112180  ...          1919141.04
#
# [2 rows x 6 columns]

# %%
df2.loc['test', ['total_vend_amnt_40','total_vend_amnt_42','total_vend_amnt_44']]-\
df2.loc['control', ['total_vend_amnt_40','total_vend_amnt_42','total_vend_amnt_44']]- 1400000
# Out:
# total_vend_amnt_40     3054.14
# total_vend_amnt_42    28336.74
# total_vend_amnt_44    22410.97
# dtype: float64

# %%
df2.loc['test', ['installcap_44']]
# Out:
# installcap_44    112180.0
# Name: test, dtype: float64

# %%
30.42*df2.loc['test', ['total_vend_amnt_40','total_vend_amnt_42','total_vend_amnt_44']]/(112180*7)
# Out:
# total_vend_amnt_40    73.228959
# total_vend_amnt_42    74.571201
# total_vend_amnt_44    74.345147
# Name: test, dtype: float64

# %%
30.42*df2.loc['control', ['total_vend_amnt_40','total_vend_amnt_42','total_vend_amnt_44']]/(28459*7)
# Out:
# total_vend_amnt_40    74.407120
# total_vend_amnt_42    75.837309
# total_vend_amnt_44    75.851118
# Name: control, dtype: float64

# %%
30.42*df2.loc['test', ['total_vend_amnt_40','total_vend_amnt_42','total_vend_amnt_44']]/(112180*7)-\
30.42*df2.loc['control', ['total_vend_amnt_40','total_vend_amnt_42','total_vend_amnt_44']]/(28459*7)
# Out:
# total_vend_amnt_40   -1.178161
# total_vend_amnt_42   -1.266108
# total_vend_amnt_44   -1.505970
# dtype: float64

# %%
df3=df.loc[(df.installcap_44!= df.installcap_42) | (df.installcap_40!= df.installcap_42) | (df.installcap_42!= df.installcap_44)]

# %%
100.0*df3.shape[1]/(df1.shape[0]+ df3.shape[1])
# Out:
# 0.43703628417522106

# %%
df3.head()
# Out:
#    vendor  ... loyalty_laundrycard_vend_amnt_44
# 9      DI  ...                              0.0
# 15     DI  ...                              0.0
# 16     DI  ...                              0.0
# 17     DI  ...                              0.0
# 60     DI  ...                              0.0
#
# [5 rows x 43 columns]
# ...
