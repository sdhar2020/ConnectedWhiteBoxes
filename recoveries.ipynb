# %%
import pandas as pd

# %%
lnk='https://www.dropbox.com/s/fo8wx3wn26nlsvr/recovery-campaigns-list%20--%2006-21-21.csv?dl=1'

# %%
df= pd.read_csv(lnk)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (1,2,8,9,10,12,27,31,34) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.isnull().sum()
# Out:
# email                              0
# firstName                     686616
# lastName                      686617
# city                          164297
# country                        90907
# timeZone                       90902
# anonymousId                   164867
# app                            90899
# app-user                      686612
# app_user                      574486
# auto_refill_enabled           686633
# brandAffinityLabel                 3
# building_id                    92837
# devices                       686662
# ip                             90899
# subscribedMessageTypeIds        7473
# laundry_card_user              96546
# emailListIds                    7473
# locale                         90899
# mobile_number                 624257
# phoneNumber                   686662
# phoneNumberDetails            686662
# profileUpdatedAt                   0
# region                        140821
# room_id                       100732
# ...
