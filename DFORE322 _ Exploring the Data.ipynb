# %% [markdown]
# # Libraries and Install
# ### Date of Analysis: Jan 1st 2022

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt

# %% [markdown]
# # Data File

# %% [markdown]
# ## File Read

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive

# %%
# %ls /gdrive/MyDrive/Forecasting/DFORE322RmDateVends.zip

df= pd.read_csv('/gdrive/MyDrive/Forecasting/DFORE322RmDateVends.zip', compression='zip')
# Out:
# /gdrive/MyDrive/Forecasting/DFORE322RmDateVends.zip

# %%
df.shape
# Out:
# (1752584, 21)

# %%
df.head()
# Out:
#   vendor  AS400ID  ... InstallCap Vends
# 0  CSCGo    85085  ...          2     2
# 1  CSCGo    85085  ...          2     3
# 2  CSCGo    85085  ...          2     2
# 3  CSCGo    85085  ...          2     3
# 4  CSCGo    85085  ...          2     1
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Data Types and NULLs

# %%
df.drop(labels= ['vendor.1', 'room_id.1', 'vendor_location_id.1'], axis=1, inplace=True)

# %%
df['TxnDate']= pd.to_datetime(df.TxnDate)

# %%
df.dtypes
# Out:
# vendor                            object
# AS400ID                            int64
# vendor_location_id                object
# Region                            object
# branch_id                          int64
# BranchName                        object
# AccountCity                       object
# AccountState                      object
# Industry                          object
# room_id                           object
# machine_type                      object
# common_area_laundry__c              bool
# zipcode                           object
# client_account_id                  int64
# year_wk                          float64
# TxnDate                   datetime64[ns]
# InstallCap                         int64
# Vends                              int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# vendor                       0
# AS400ID                      0
# vendor_location_id           0
# Region                       0
# branch_id                    0
# BranchName                   0
# AccountCity                  0
# AccountState                 0
# Industry                  7661
# room_id                      0
# machine_type                 0
# common_area_laundry__c       0
# zipcode                      0
# client_account_id            0
# year_wk                      0
# TxnDate                      0
# InstallCap                   0
# Vends                        0
# dtype: int64

# %% [markdown]
# ## Aggregate Statistics
