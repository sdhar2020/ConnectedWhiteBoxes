# %%
! pip install office365-rest-client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 246 kB 10.3 MB/s
# ...
#      |████████████████████████████████| 55 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 46.8 MB/s
# ...

# %%
import io
import json
import pandas as pd
from office365.runtime.auth.authentication_context import AuthenticationContext
from office365.runtime.auth.user_credential import UserCredential
from office365.runtime.http.request_options import RequestOptions
from office365.sharepoint.client_context import ClientContext
from office365.sharepoint.files.file import File
from io import BytesIO

# %%
'https://cscserviceworks-my.sharepoint.com/:x:/g/personal/bdehury_cscsw_com/EfXXmz-PLShBqD5XHsz_iXQBKhCI5CxaHi-XQaw164l3RA?e=Idz3Sr'
# Out:
# 'https://cscserviceworks-my.sharepoint.com/:x:/g/personal/bdehury_cscsw_com/EfXXmz-PLShBqD5XHsz_iXQBKhCI5CxaHi-XQaw164l3RA?e=Idz3Sr'

# %%
url = 'https://cscserviceworks-my.sharepoint.com/'
username = 'sdhar@cscsw.com'
password = 'Aug3!2019'
relative_url = '/:x:/g/personal/bdehury_cscsw_com/EfXXmz-PLShBqD5XHsz_iXQBKhCI5CxaHi-XQaw164l3RA?e=Idz3Sr'

# %%
ctx_auth = AuthenticationContext(url)
if ctx_auth.acquire_token_for_user(username, password):
  ctx = ClientContext(url, ctx_auth)
  web = ctx.web
  ctx.load(web)
  ctx.execute_query()
  print("Web title: {0}".format(web.properties['Title']))

else:
  print(ctx_auth.get_last_error())
# Out:
# Cannot get security assertion for user sdhar@cscsw.com from https://cscsw.okta.com/app/office365/exk3fiug2dstsBYB0357/sso/wsfed/active
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-6e24b06b3aee> in <module>()
#       1 ctx_auth = AuthenticationContext(url)
# ----> 2 if ctx_auth.acquire_token_for_user(username, password):
#       3   ctx = ClientContext(url, ctx_auth)
#       4   web = ctx.web
#       5   ctx.load(web)
#
# /usr/local/lib/python3.7/dist-packages/office365/runtime/auth/authentication_context.py in acquire_token_for_user(self, username, password)
#      35         """
#      36         self.provider = SamlTokenProvider(self.url, username, password)
# ---> 37         if not self.provider.acquire_token():
#      38             raise ValueError('Acquire token failed: {0}'.format(self.provider.error))
#      39         return True
#
# ...
